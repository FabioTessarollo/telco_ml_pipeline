# %% [markdown]
# # INTERNET Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import average_precision_score, roc_auc_score, accuracy_score, f1_score

import optuna
import catboost as cb
import xgboost as xgb
import lightgbm as lgb

# %%
df = pd.read_csv('preprocessed_data/df_train_internet_only.csv')

# %%
df.head()
# Out:
#    seniorcitizen  partner  dependents  tenure  phoneservice  onlinesecurity  \
# 0          False     True       False    51.0         False           False
# 1           True    False       False    12.0         False           False
# 2          False     True        True     7.0         False            True
# 3          False     True       False    56.0         False           False
# 4           True     True       False    58.0         False           False
#
#    onlinebackup  deviceprotection  techsupport  streamingtv  ...  churn  \
# 0          True             False        False         True  ...  False
# 1          True             False        False        False  ...  False
# 2         False             False         True        False  ...   True
# 3         False              True         True         True  ...  False
# 4          True              True        False        False  ...   True
#
#    is_male  internetservice_is_fiber_optic  contract_month-to-month  \
# 0    False                           False                     True
# 1     True                           False                     True
# 2     True                           False                     True
# 3     True                           False                    False
# 4     True                           False                     True
#
#    contract_one_year  contract_two_year  \
# 0              False              False
# 1              False              False
# 2              False              False
# 3               True              False
# 4              False              False
#
#    paymentmethod_bank_transfer_(automatic)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    paymentmethod_credit_card_(automatic)  paymentmethod_electronic_check  \
# 0                                  False                            True
# 1                                   True                           False
# 2                                  False                            True
# 3                                  False                           False
# 4                                  False                            True
#
#    paymentmethod_mailed_check
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
# [5 rows x 24 columns]

# %%
df = df.drop('internetservice_is_fiber_optic', axis = 1) #Only Internet customers have only DSL Internet service
df = df.drop('phoneservice', axis = 1) #All false, as this is a condition of only internet subset

# %%
num_col = ['tenure', 'totalcharges', 'monthlycharges']
target = 'churn'
X_col = [c for c in df.columns if c != target]
cat_col = [c for c in X_col if c not in num_col]

# %%
# Compute correlation matrix
correlation_matrix = df.corr()

# Extract correlations with 'Churn'
churn_correlation = correlation_matrix['churn'].sort_values(ascending=False)

# Print correlations
print("Correlation with 'Churn':")
print(churn_correlation)

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=False, fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# Plot correlations with 'Churn' as a bar chart
plt.figure(figsize=(10, 6))
churn_correlation.drop('churn').plot(kind='bar', color='skyblue')
plt.title("Correlation of Features with 'Churn'")
plt.ylabel("Correlation Coefficient")
plt.xlabel("Features")
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Correlation with 'Churn':
# churn                                      1.000000
# contract_month-to-month                    0.416860
# paymentmethod_electronic_check             0.246758
# seniorcitizen                              0.204010
# paperlessbilling                           0.157220
# is_male                                    0.030796
# paymentmethod_mailed_check                -0.009298
# streamingmovies                           -0.024813
# paymentmethod_bank_transfer_(automatic)   -0.108917
# streamingtv                               -0.109068
# partner                                   -0.112918
# onlinebackup                              -0.152186
# paymentmethod_credit_card_(automatic)     -0.163156
# contract_one_year                         -0.179873
# deviceprotection                          -0.184914
# dependents                                -0.192869
# monthlycharges                            -0.259025
# onlinesecurity                            -0.275671
# contract_two_year                         -0.314449
# techsupport                               -0.316373
# totalcharges                              -0.365058
# tenure                                    -0.389681
# Name: churn, dtype: float64

# %%
sns.histplot(data=df, x='churn')
# Out:
# <Axes: xlabel='churn', ylabel='Count'>

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))
for col, ax in zip(num_col, axes):
    sns.histplot(
        data=df, x=col, kde=True, ax=ax, hue=target, binwidth=df[col].std() /5, edgecolor=None
    )

# %%
probability_of_churn_given_flag = df[df[target]][cat_col].sum() / df[cat_col].sum()
probability_of_churn_given_flag = probability_of_churn_given_flag.sort_values(ascending = False)

plt.figure(figsize=(10, 6))
sns.barplot(data=probability_of_churn_given_flag, orient= 'h')
plt.xlabel('Mean Value')
plt.ylabel('Categories')
plt.show()

# %%
scaler = RobustScaler()
df_scaled = df.copy()
df_scaled.loc[:, num_col] = scaler.fit_transform(df_scaled[num_col])

# %%
pca = PCA()
X_pca = pca.fit_transform(df_scaled[X_col])
importances = pca.explained_variance_ratio_ / np.sum(pca.explained_variance_ratio_)
print(pd.Series(importances)[:3])
# Out:
# 0    0.308159
# 1    0.115089
# 2    0.061302
# dtype: float64

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=df[target], cmap="viridis", alpha=0.7)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Scatter Plot")
plt.colorbar(label="Target")
plt.grid()
plt.show()

# %%
fig = px.scatter_3d(
    x=X_pca[:, 0],
    y=X_pca[:, 1],
    z=X_pca[:, 2],
    color=df[target],
    labels={"x": "Principal Component 1", "y": "Principal Component 2", "z": "Principal Component 3"},
    title="3D PCA Scatter Plot",
)

fig.update_traces(marker={"size": 3})
fig.update_layout(width=1000, height=800)
fig.show()

# %%
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(df_scaled[X_col])

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=df[target], cmap="viridis", alpha=0.7)
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.title("t-SNE Scatter Plot")
plt.colorbar(label="Target")
plt.grid()
plt.show()

# %% [markdown]
# ## Modelling

# %%
X = df[X_col]
y = df[target]

# %%
df_test = pd.read_csv('preprocessed_data/df_test_internet_only.csv')
X_test = df_test[X_col]
y_test = df_test[target]

# %% [markdown]
# ## CatBoost

# %% [markdown]
# #### Parameters research

# %%
def objective(trial):
    param = {
        'iterations': trial.suggest_int('iterations', 500, 1000),
        'depth': trial.suggest_int('depth', 4, 8),
        'learning_rate': trial.suggest_float('learning_rate', 1e-2, 0.1),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 16, 20),
        'subsample': trial.suggest_float('subsample', 0.4, 0.7),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 0, 5),
        'random_strength': trial.suggest_float('random_strength', 0.1, 2),
        'loss_function': 'Logloss',
        'eval_metric': 'Accuracy',
        'task_type': 'CPU',
    }

    
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    scores = []
    
    for train_index, valid_index in kf.split(X, y):
        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
        
        scaler = MinMaxScaler()
        X_train.loc[:, num_col] = scaler.fit_transform(X_train[num_col])
        X_valid.loc[:, num_col] = scaler.transform(X_valid[num_col])
    
        # Create CatBoost Pool
        train_pool = cb.Pool(X_train, y_train)
        valid_pool = cb.Pool(X_valid, y_valid)
        
        # Initialize and train model
        model = cb.CatBoostClassifier(**param, 
                                      verbose=False, 
                                      early_stopping_rounds=15
                                      )
        model.fit(train_pool, 
                  eval_set=valid_pool, 
                  plot=False)
        
        # Predict and calculate accuracy
        preds = model.predict(valid_pool)
        scores.append(roc_auc_score(y_valid, preds))
    
    mean_score = np.mean(scores)
    return mean_score

# Create Optuna study
study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42),  pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=3))

# Optimize
study.optimize(objective, n_trials=20)

# Print best parameters
print("Best trial:", study.best_trial.params)
# Out:
# [I 2024-12-14 16:28:41,754] A new study created in memory with name: no-name-bce7f65d-a344-4104-9667-c17c4cc4ea73
# [I 2024-12-14 16:28:43,757] Trial 0 finished with value: 0.6891674484052533 and parameters: {'iterations': 687, 'depth': 8, 'learning_rate': 0.07587945476302646, 'l2_leaf_reg': 18.394633936788146, 'subsample': 0.44680559213273097, 'min_data_in_leaf': 0, 'random_strength': 0.21035886311957896}. Best is trial 0 with value: 0.6891674484052533.
# [I 2024-12-14 16:28:45,234] Trial 1 finished with value: 0.7100525998391851 and parameters: {'iterations': 933, 'depth': 7, 'learning_rate': 0.0737265320016441, 'l2_leaf_reg': 16.082337977183208, 'subsample': 0.6909729556485982, 'min_data_in_leaf': 4, 'random_strength': 0.5034443102887247}. Best is trial 1 with value: 0.7100525998391851.
# [I 2024-12-14 16:28:46,181] Trial 2 finished with value: 0.6998207585097829 and parameters: {'iterations': 591, 'depth': 4, 'learning_rate': 0.0373818018663584, 'l2_leaf_reg': 18.09902572652895, 'subsample': 0.5295835055926348, 'min_data_in_leaf': 1, 'random_strength': 1.262520499972521}. Best is trial 1 with value: 0.7100525998391851.
# [I 2024-12-14 16:28:47,449] Trial 3 finished with value: 0.7037412891986063 and parameters: {'iterations': 569, 'depth': 5, 'learning_rate': 0.04297256589643226, 'l2_leaf_reg': 17.824279936868145, 'subsample': 0.6355527884179041, 'min_data_in_leaf': 1, 'random_strength': 1.077045432985862}. Best is trial 1 with value: 0.7100525998391851.
# [I 2024-12-14 16:28:48,787] Trial 4 finished with value: 0.7098113776467435 and parameters: {'iterations': 796, 'depth': 4, 'learning_rate': 0.06467903667112945, 'l2_leaf_reg': 16.682096494749167, 'subsample': 0.41951547789558385, 'min_data_in_leaf': 5, 'random_strength': 1.9347008628416629}. Best is trial 1 with value: 0.7100525998391851.
# [I 2024-12-14 16:28:50,297] Trial 5 finished with value: 0.704220718306084 and parameters: {'iterations': 905, 'depth': 5, 'learning_rate': 0.018790490260574548, 'l2_leaf_reg': 18.736932106048627, 'subsample': 0.5320457481218803, 'min_data_in_leaf': 0, 'random_strength': 1.0408361292114134}. Best is trial 1 with value: 0.7100525998391851.
# [I 2024-12-14 16:28:52,543] Trial 6 finished with value: 0.6987017555615116 and parameters: {'iterations': 517, 'depth': 8, 'learning_rate': 0.03329019834400153, 'l2_leaf_reg': 18.65008913741593, 'subsample': 0.4935133228268233, 'min_data_in_leaf': 3, 'random_strength': 1.1387495307522313}. Best is trial 1 with value: 0.7100525998391851.
# [I 2024-12-14 16:28:54,419] Trial 7 finished with value: 0.6970503886357545 and parameters: {'iterations': 592, 'depth': 8, 'learning_rate': 0.07976195410250031, 'l2_leaf_reg': 19.757995766256755, 'subsample': 0.6684482051282946, 'min_data_in_leaf': 3, 'random_strength': 1.851561046543922}. Best is trial 1 with value: 0.7100525998391851.
# [I 2024-12-14 16:28:55,642] Trial 8 finished with value: 0.7194602653444117 and parameters: {'iterations': 544, 'depth': 4, 'learning_rate': 0.014070456001948426, 'l2_leaf_reg': 17.301321323053056, 'subsample': 0.5166031869068446, 'min_data_in_leaf': 1, 'random_strength': 1.6746012673886657}. Best is trial 8 with value: 0.7194602653444117.
# [I 2024-12-14 16:28:56,982] Trial 9 finished with value: 0.6962231975341732 and parameters: {'iterations': 678, 'depth': 5, 'learning_rate': 0.058842647484242366, 'l2_leaf_reg': 16.56369689989905, 'subsample': 0.6406590942262118, 'min_data_in_leaf': 0, 'random_strength': 1.975085179540983}. Best is trial 8 with value: 0.7194602653444117.
# [I 2024-12-14 16:28:58,445] Trial 10 finished with value: 0.7094160412757974 and parameters: {'iterations': 757, 'depth': 6, 'learning_rate': 0.09725833997090795, 'l2_leaf_reg': 17.38740356562649, 'subsample': 0.5920265507402669, 'min_data_in_leaf': 2, 'random_strength': 1.4876971008933184}. Best is trial 8 with value: 0.7194602653444117.
# [I 2024-12-14 16:29:00,099] Trial 11 finished with value: 0.7047256097560975 and parameters: {'iterations': 989, 'depth': 7, 'learning_rate': 0.010610298348162999, 'l2_leaf_reg': 16.114427338344225, 'subsample': 0.58472111241213, 'min_data_in_leaf': 5, 'random_strength': 0.39139954380754094}. Best is trial 8 with value: 0.7194602653444117.
# [I 2024-12-14 16:29:01,679] Trial 12 finished with value: 0.7111850040203699 and parameters: {'iterations': 861, 'depth': 7, 'learning_rate': 0.09441060853364314, 'l2_leaf_reg': 17.346377510546255, 'subsample': 0.48009732188361093, 'min_data_in_leaf': 4, 'random_strength': 0.6028533026311803}. Best is trial 8 with value: 0.7194602653444117.
# [I 2024-12-14 16:29:03,226] Trial 13 finished with value: 0.7051045296167248 and parameters: {'iterations': 845, 'depth': 6, 'learning_rate': 0.09289794459711755, 'l2_leaf_reg': 17.39053372198633, 'subsample': 0.4806389881738024, 'min_data_in_leaf': 2, 'random_strength': 0.7513186477060009}. Best is trial 8 with value: 0.7194602653444117.
# [I 2024-12-14 16:29:04,807] Trial 14 finished with value: 0.7169207317073171 and parameters: {'iterations': 826, 'depth': 7, 'learning_rate': 0.04943171507420211, 'l2_leaf_reg': 17.11996390108122, 'subsample': 0.4856063049892779, 'min_data_in_leaf': 4, 'random_strength': 0.7448951679663762}. Best is trial 8 with value: 0.7194602653444117.
# [I 2024-12-14 16:29:06,215] Trial 15 finished with value: 0.7269649557759313 and parameters: {'iterations': 696, 'depth': 6, 'learning_rate': 0.02697449084906821, 'l2_leaf_reg': 16.92644070554812, 'subsample': 0.401622626018785, 'min_data_in_leaf': 4, 'random_strength': 1.5280655071499984}. Best is trial 15 with value: 0.7269649557759313.
# [I 2024-12-14 16:29:07,397] Trial 16 finished with value: 0.7218121817207183 and parameters: {'iterations': 683, 'depth': 4, 'learning_rate': 0.02800995157266742, 'l2_leaf_reg': 16.649781919452593, 'subsample': 0.4125023668330107, 'min_data_in_leaf': 1, 'random_strength': 1.6115664251358885}. Best is trial 15 with value: 0.7269649557759313.
# [I 2024-12-14 16:29:08,670] Trial 17 finished with value: 0.7048602921468775 and parameters: {'iterations': 673, 'depth': 5, 'learning_rate': 0.025631207509175198, 'l2_leaf_reg': 16.70989842225283, 'subsample': 0.4068672081704099, 'min_data_in_leaf': 3, 'random_strength': 1.5029472408745925}. Best is trial 15 with value: 0.7269649557759313.
# [I 2024-12-14 16:29:10,081] Trial 18 finished with value: 0.7046251005092468 and parameters: {'iterations': 730, 'depth': 6, 'learning_rate': 0.02533319273785761, 'l2_leaf_reg': 19.438599500782207, 'subsample': 0.44136097682206876, 'min_data_in_leaf': 2, 'random_strength': 1.3911706108184705}. Best is trial 15 with value: 0.7269649557759313.
# [I 2024-12-14 16:29:11,543] Trial 19 finished with value: 0.6986317341195389 and parameters: {'iterations': 633, 'depth': 6, 'learning_rate': 0.027567888344383625, 'l2_leaf_reg': 16.49699440466389, 'subsample': 0.44302328162578414, 'min_data_in_leaf': 4, 'random_strength': 1.6947269388820374}. Best is trial 15 with value: 0.7269649557759313.
# Best trial: {'iterations': 696, 'depth': 6, 'learning_rate': 0.02697449084906821, 'l2_leaf_reg': 16.92644070554812, 'subsample': 0.401622626018785, 'min_data_in_leaf': 4, 'random_strength': 1.5280655071499984}

# %% [markdown]
# #### Testing

# %%
best_params = {'iterations': 696, 'depth': 6, 'learning_rate': 0.02697449084906821, 'l2_leaf_reg': 16.92644070554812, 'subsample': 0.401622626018785, 'min_data_in_leaf': 4, 'random_strength': 1.5280655071499984}
model = cb.CatBoostClassifier(**best_params, verbose=False)
train_pool = cb.Pool(X, y)
test_pool = cb.Pool(X_test, y_test)
model.fit(train_pool)

# %%
print('CatBoost scores')
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"RocAuc: {roc_auc_score(y_test, y_pred)}")
print(f"F1 : {f1_score(y_test, y_pred)}")
# Out:
# CatBoost scores
# Accuracy: 0.7956204379562044
# RocAuc: 0.6473443746430612
# F1 : 0.46153846153846156

# %% [markdown]
# ## XGBoost

# %% [markdown]
# #### Parameters research

# %%
def objective(trial):
    param = {
        "objective": "binary:logistic",
        "eval_metric": "aucpr",
        'n_estimators': trial.suggest_int('n_estimators', 800, 1200), 
        "booster": trial.suggest_categorical("booster", ["gbtree", "dart"]),
        "lambda": trial.suggest_float("lambda", 1e-3, 2),
        "alpha": trial.suggest_float("alpha", 1e-3, 2),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "eta": trial.suggest_float("eta", 1e-2, 0.3),
        "gamma": trial.suggest_float("gamma", 1e-3, 3),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 7),
        "subsample": trial.suggest_float("subsample", 0.6, 0.95),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 0.95),
        "grow_policy": trial.suggest_categorical(
            "grow_policy", ["depthwise", "lossguide"]
        ),
        "max_bin": trial.suggest_int("max_bin", 64, 255)
    }

    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    scores = []
    for train_index, valid_index in kf.split(X, y):
        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
    
        model = xgb.XGBClassifier(**param, early_stopping_rounds=15)
        model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)], verbose=False)
        preds = model.predict(X_valid)
        scores.append(accuracy_score(y_valid, preds))
    
    mean_score = np.mean(scores)   
    return mean_score

study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42), pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=3))
study.optimize(objective, n_trials=20)

print("Best trial:", study.best_trial.params)
# Out:
# [I 2024-12-14 16:29:13,509] A new study created in memory with name: no-name-45997f01-6ceb-4199-9f97-bb67ff779ead
# [I 2024-12-14 16:29:14,174] Trial 0 finished with value: 0.7560606060606061 and parameters: {'n_estimators': 950, 'booster': 'gbtree', 'lambda': 1.197718309909876, 'alpha': 0.31288126224443064, 'max_depth': 4, 'eta': 0.026844247528777843, 'gamma': 2.5986622611790304, 'min_child_weight': 5, 'subsample': 0.8478254022286159, 'colsample_bytree': 0.6072045730035308, 'grow_policy': 'depthwise', 'max_bin': 104}. Best is trial 0 with value: 0.7560606060606061.
# [I 2024-12-14 16:29:17,428] Trial 1 finished with value: 0.7981818181818182 and parameters: {'n_estimators': 872, 'booster': 'dart', 'lambda': 1.0499881068328434, 'alpha': 0.8644580922655895, 'max_depth': 5, 'eta': 0.18743733946949004, 'gamma': 0.41934208809547346, 'min_child_weight': 3, 'subsample': 0.7282266451527921, 'colsample_bytree': 0.7596244944759625, 'grow_policy': 'depthwise', 'max_bin': 162}. Best is trial 1 with value: 0.7981818181818182.
# [I 2024-12-14 16:29:18,427] Trial 2 finished with value: 0.7945117845117846 and parameters: {'n_estimators': 1037, 'booster': 'dart', 'lambda': 0.34187772325089577, 'alpha': 0.13103813437757375, 'max_depth': 10, 'eta': 0.2900332895916222, 'gamma': 2.425383647001267, 'min_child_weight': 3, 'subsample': 0.6341852399022343, 'colsample_bytree': 0.8394815592792548, 'grow_policy': 'depthwise', 'max_bin': 159}. Best is trial 1 with value: 0.7981818181818182.
# [I 2024-12-14 16:29:19,030] Trial 3 finished with value: 0.8018855218855221 and parameters: {'n_estimators': 813, 'booster': 'gbtree', 'lambda': 1.32538204642361, 'alpha': 0.6241104411027325, 'max_depth': 7, 'eta': 0.1685459810095511, 'gamma': 0.5553785121210556, 'min_child_weight': 7, 'subsample': 0.87129648817639, 'colsample_bytree': 0.9288246295474661, 'grow_policy': 'depthwise', 'max_bin': 240}. Best is trial 3 with value: 0.8018855218855221.
# [I 2024-12-14 16:29:19,759] Trial 4 finished with value: 0.7853535353535352 and parameters: {'n_estimators': 835, 'booster': 'gbtree', 'lambda': 0.6513353311957655, 'alpha': 0.7779659020892746, 'max_depth': 5, 'eta': 0.2503338776540595, 'gamma': 1.0709032267540741, 'min_child_weight': 2, 'subsample': 0.789943629105387, 'colsample_bytree': 0.6493234787411669, 'grow_policy': 'depthwise', 'max_bin': 253}. Best is trial 3 with value: 0.8018855218855221.
# [I 2024-12-14 16:29:20,421] Trial 5 finished with value: 0.7963299663299663 and parameters: {'n_estimators': 1109, 'booster': 'gbtree', 'lambda': 1.6311073954812134, 'alpha': 1.4140078303513866, 'max_depth': 8, 'eta': 0.23366840053892426, 'gamma': 0.223059910550537, 'min_child_weight': 3, 'subsample': 0.6405541708337954, 'colsample_bytree': 0.9020861990564577, 'grow_policy': 'depthwise', 'max_bin': 76}. Best is trial 3 with value: 0.8018855218855221.
# [I 2024-12-14 16:29:22,660] Trial 6 finished with value: 0.7505050505050506 and parameters: {'n_estimators': 924, 'booster': 'dart', 'lambda': 1.275477385239071, 'alpha': 1.7745382724100767, 'max_depth': 6, 'eta': 0.04468233132210749, 'gamma': 2.140021116881762, 'min_child_weight': 6, 'subsample': 0.7964470191493236, 'colsample_bytree': 0.8698385129840963, 'grow_policy': 'lossguide', 'max_bin': 146}. Best is trial 3 with value: 0.8018855218855221.
# [I 2024-12-14 16:29:23,231] Trial 7 finished with value: 0.8074747474747473 and parameters: {'n_estimators': 810, 'booster': 'gbtree', 'lambda': 1.273184412116297, 'alpha': 0.629397606171577, 'max_depth': 7, 'eta': 0.27319427743856695, 'gamma': 0.748627395217476, 'min_child_weight': 3, 'subsample': 0.864442898490067, 'colsample_bytree': 0.6800793579220679, 'grow_policy': 'lossguide', 'max_bin': 94}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:23,716] Trial 8 finished with value: 0.8036026936026935 and parameters: {'n_estimators': 1172, 'booster': 'gbtree', 'lambda': 1.7430497197852477, 'alpha': 1.6075404817213297, 'max_depth': 4, 'eta': 0.26884210956209353, 'gamma': 1.6184873835050364, 'min_child_weight': 6, 'subsample': 0.9136319549732226, 'colsample_bytree': 0.7113012162401523, 'grow_policy': 'lossguide', 'max_bin': 146}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:24,451] Trial 9 finished with value: 0.7578451178451179 and parameters: {'n_estimators': 1128, 'booster': 'gbtree', 'lambda': 1.0219838578525537, 'alpha': 0.8354045952944092, 'max_depth': 4, 'eta': 0.044760956526768016, 'gamma': 1.0135078990394801, 'min_child_weight': 7, 'subsample': 0.7131210262072643, 'colsample_bytree': 0.7815767176101781, 'grow_policy': 'depthwise', 'max_bin': 250}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:27,053] Trial 10 finished with value: 0.7795959595959596 and parameters: {'n_estimators': 1005, 'booster': 'dart', 'lambda': 0.01608709131327013, 'alpha': 1.2799565880603438, 'max_depth': 9, 'eta': 0.1097215877927743, 'gamma': 1.657034158554231, 'min_child_weight': 1, 'subsample': 0.9361291961991683, 'colsample_bytree': 0.6810256552536735, 'grow_policy': 'lossguide', 'max_bin': 65}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:27,572] Trial 11 finished with value: 0.798114478114478 and parameters: {'n_estimators': 1182, 'booster': 'gbtree', 'lambda': 1.9681269162106334, 'alpha': 1.8781102701133876, 'max_depth': 3, 'eta': 0.2994481434094266, 'gamma': 1.6231543526560892, 'min_child_weight': 5, 'subsample': 0.9363695524522827, 'colsample_bytree': 0.7209928108368933, 'grow_policy': 'lossguide', 'max_bin': 119}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:28,100] Trial 12 finished with value: 0.7963636363636364 and parameters: {'n_estimators': 1081, 'booster': 'gbtree', 'lambda': 1.7296318719764474, 'alpha': 1.2899442774780143, 'max_depth': 7, 'eta': 0.23782345591039064, 'gamma': 0.9716713839887975, 'min_child_weight': 5, 'subsample': 0.8674406013925513, 'colsample_bytree': 0.7073335118747451, 'grow_policy': 'lossguide', 'max_bin': 195}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:28,634] Trial 13 finished with value: 0.7962962962962963 and parameters: {'n_estimators': 1191, 'booster': 'gbtree', 'lambda': 1.5660128801415487, 'alpha': 0.46661903478136657, 'max_depth': 6, 'eta': 0.20364331041721873, 'gamma': 2.019175560734792, 'min_child_weight': 4, 'subsample': 0.8871652886153422, 'colsample_bytree': 0.78420241143735, 'grow_policy': 'lossguide', 'max_bin': 109}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:29,255] Trial 14 finished with value: 0.7890909090909091 and parameters: {'n_estimators': 928, 'booster': 'gbtree', 'lambda': 1.9653896273988316, 'alpha': 1.5127211479273628, 'max_depth': 8, 'eta': 0.11247792176726606, 'gamma': 1.346456400523061, 'min_child_weight': 4, 'subsample': 0.8394683493869257, 'colsample_bytree': 0.6442877915437235, 'grow_policy': 'lossguide', 'max_bin': 186}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:29,762] Trial 15 finished with value: 0.7945454545454546 and parameters: {'n_estimators': 1036, 'booster': 'gbtree', 'lambda': 0.7174221792962936, 'alpha': 1.0940952181383379, 'max_depth': 3, 'eta': 0.2788941974949365, 'gamma': 0.7285894197471955, 'min_child_weight': 6, 'subsample': 0.9087807708698861, 'colsample_bytree': 0.739139293644109, 'grow_policy': 'lossguide', 'max_bin': 133}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:30,426] Trial 16 finished with value: 0.7908080808080807 and parameters: {'n_estimators': 878, 'booster': 'gbtree', 'lambda': 1.5195239780153398, 'alpha': 0.002607514099392305, 'max_depth': 5, 'eta': 0.14271721900810916, 'gamma': 1.315115116808208, 'min_child_weight': 1, 'subsample': 0.8164506803273228, 'colsample_bytree': 0.8098376997903733, 'grow_policy': 'lossguide', 'max_bin': 90}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:30,942] Trial 17 finished with value: 0.790942760942761 and parameters: {'n_estimators': 973, 'booster': 'gbtree', 'lambda': 0.7933419595455597, 'alpha': 1.6258949356416055, 'max_depth': 8, 'eta': 0.26178583123144766, 'gamma': 2.864323889522008, 'min_child_weight': 2, 'subsample': 0.7564579779766779, 'colsample_bytree': 0.6798534141023758, 'grow_policy': 'lossguide', 'max_bin': 195}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:32,445] Trial 18 finished with value: 0.7853535353535355 and parameters: {'n_estimators': 1147, 'booster': 'dart', 'lambda': 1.7643733365135574, 'alpha': 1.1457740349078027, 'max_depth': 4, 'eta': 0.21745764639836174, 'gamma': 0.12018848747655131, 'min_child_weight': 6, 'subsample': 0.908273573497773, 'colsample_bytree': 0.6051011860249067, 'grow_policy': 'lossguide', 'max_bin': 221}. Best is trial 7 with value: 0.8074747474747473.
# [I 2024-12-14 16:29:32,934] Trial 19 finished with value: 0.7871043771043771 and parameters: {'n_estimators': 1064, 'booster': 'gbtree', 'lambda': 1.4550018785596657, 'alpha': 1.978933049808698, 'max_depth': 6, 'eta': 0.2567938329412944, 'gamma': 1.864065927909251, 'min_child_weight': 2, 'subsample': 0.8272918583883733, 'colsample_bytree': 0.687807595625362, 'grow_policy': 'lossguide', 'max_bin': 134}. Best is trial 7 with value: 0.8074747474747473.
# Best trial: {'n_estimators': 810, 'booster': 'gbtree', 'lambda': 1.273184412116297, 'alpha': 0.629397606171577, 'max_depth': 7, 'eta': 0.27319427743856695, 'gamma': 0.748627395217476, 'min_child_weight': 3, 'subsample': 0.864442898490067, 'colsample_bytree': 0.6800793579220679, 'grow_policy': 'lossguide', 'max_bin': 94}

# %% [markdown]
# #### Testing

# %%
best_params = {'n_estimators': 810, 'booster': 'gbtree', 'lambda': 1.273184412116297, 'alpha': 0.629397606171577, 'max_depth': 7, 'eta': 0.27319427743856695, 'gamma': 0.748627395217476, 'min_child_weight': 3, 'subsample': 0.864442898490067, 'colsample_bytree': 0.6800793579220679, 'grow_policy': 'lossguide', 'max_bin': 94}
model = xgb.XGBClassifier(**best_params)
model.fit(X, y)
# Out:
# XGBClassifier(alpha=0.13103813437757375, base_score=None, booster='dart',
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8394815592792548, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eta=0.2900332895916222, eval_metric=None, feature_types=None,
#               gamma=2.425383647001267, grow_policy='depthwise',
#               importance_type=None, interaction_constraints=None,
#               lambda=0.34187772325089577, learning_rate=None, max_bin=159,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1037, ...)

# %%
print('XGBoost scores')
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"RocAuc: {roc_auc_score(y_test, y_pred)}")
print(f"F1 : {f1_score(y_test, y_pred)}")
# Out:
# XGBoost scores
# Accuracy: 0.7664233576642335
# RocAuc: 0.6279268989149058
# F1 : 0.42857142857142855

# %% [markdown]
# ## LGBM

# %% [markdown]
# #### Parameters research

# %%
def objective(trial):
    param = {
        'num_leaves': trial.suggest_int('num_leaves', 40, 70),
        'max_depth': trial.suggest_int('max_depth', 6, 14),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 40, 70),
        'lambda_l1': trial.suggest_float('lambda_l1', 0.1, 2),
        'lambda_l2': trial.suggest_float('lambda_l2', 0.1, 2),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 0.95),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 0.95),
        'bagging_freq': trial.suggest_int('bagging_freq', 5, 15),
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': 'binary_error',
        'n_estimators': trial.suggest_int('n_estimators', 100, 500)        
    }
    
    kf = StratifiedKFold(n_splits=20, shuffle=True, random_state=42)
    accuracies = []
    
    for train_index, valid_index in kf.split(X, y):
        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

        scaler = MinMaxScaler()
        X_train.loc[:, num_col] = scaler.fit_transform(X_train[num_col])
        X_valid.loc[:, num_col] = scaler.transform(X_valid[num_col])
        
        model = lgb.LGBMClassifier(**param, early_stopping_rounds=25, verbose=-1)
        model.fit(X_train, y_train, 
                  eval_set=[(X_valid, y_valid)], 
                  eval_metric='binary_error')
        
        preds = model.predict(X_valid)
        accuracies.append(accuracy_score(y_valid, preds))
    
    mean_accuracy = np.mean(accuracies)
    return mean_accuracy

# Create Optuna study
study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42), pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=3))

# Optimize
study.optimize(objective, n_trials=20)

# Print best parameters
print("Best trial:", study.best_trial.params)
# Out:
# [I 2024-12-14 16:31:23,755] A new study created in memory with name: no-name-01610362-84c3-4cdb-a0ba-9d369ed4e839
# [I 2024-12-14 16:31:25,243] Trial 0 finished with value: 0.82744708994709 and parameters: {'num_leaves': 51, 'max_depth': 14, 'learning_rate': 0.07587945476302646, 'min_data_in_leaf': 58, 'lambda_l1': 0.39643541684062933, 'lambda_l2': 0.39638958863878504, 'feature_fraction': 0.6203292642588698, 'bagging_fraction': 0.9031616510212273, 'bagging_freq': 11, 'n_estimators': 383}. Best is trial 0 with value: 0.82744708994709.
# [I 2024-12-14 16:31:26,584] Trial 1 finished with value: 0.8146164021164022 and parameters: {'num_leaves': 40, 'max_depth': 14, 'learning_rate': 0.08491983767203796, 'min_data_in_leaf': 46, 'lambda_l1': 0.4454674376934912, 'lambda_l2': 0.4484685687215243, 'feature_fraction': 0.7064847850358382, 'bagging_fraction': 0.7836647510712832, 'bagging_freq': 9, 'n_estimators': 216}. Best is trial 0 with value: 0.82744708994709.
# [I 2024-12-14 16:31:27,479] Trial 2 finished with value: 0.7541666666666667 and parameters: {'num_leaves': 58, 'max_depth': 7, 'learning_rate': 0.03629301836816964, 'min_data_in_leaf': 51, 'lambda_l1': 0.9665329700123682, 'lambda_l2': 1.5918343266467259, 'feature_fraction': 0.6698858237554259, 'bagging_fraction': 0.779982053444764, 'bagging_freq': 11, 'n_estimators': 118}. Best is trial 0 with value: 0.82744708994709.
# [I 2024-12-14 16:31:28,294] Trial 3 finished with value: 0.750462962962963 and parameters: {'num_leaves': 58, 'max_depth': 7, 'learning_rate': 0.015854643368675158, 'min_data_in_leaf': 69, 'lambda_l1': 1.9347008628416629, 'lambda_l2': 1.6359549614212763, 'feature_fraction': 0.7066148192106797, 'bagging_fraction': 0.6341852399022343, 'bagging_freq': 12, 'n_estimators': 276}. Best is trial 0 with value: 0.82744708994709.
# [I 2024-12-14 16:31:29,048] Trial 4 finished with value: 0.750462962962963 and parameters: {'num_leaves': 43, 'max_depth': 10, 'learning_rate': 0.013094966900369657, 'min_data_in_leaf': 68, 'lambda_l1': 0.5916819650400321, 'lambda_l2': 1.3587923402725657, 'feature_fraction': 0.7090988766312938, 'bagging_fraction': 0.7820238074122338, 'bagging_freq': 11, 'n_estimators': 174}. Best is trial 0 with value: 0.82744708994709.
# [I 2024-12-14 16:31:30,083] Trial 5 finished with value: 0.8331349206349208 and parameters: {'num_leaves': 70, 'max_depth': 12, 'learning_rate': 0.09455490474077703, 'min_data_in_leaf': 67, 'lambda_l1': 1.2360099597410619, 'lambda_l2': 1.851561046543922, 'feature_fraction': 0.6309723757181718, 'bagging_fraction': 0.6685940018467008, 'bagging_freq': 5, 'n_estimators': 230}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:31,438] Trial 6 finished with value: 0.8310846560846562 and parameters: {'num_leaves': 52, 'max_depth': 8, 'learning_rate': 0.08458637582367365, 'min_data_in_leaf': 51, 'lambda_l1': 0.6337755684060234, 'lambda_l2': 1.131122558000672, 'feature_fraction': 0.6493234787411669, 'bagging_fraction': 0.8807689432639139, 'bagging_freq': 5, 'n_estimators': 495}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:32,169] Trial 7 finished with value: 0.750462962962963 and parameters: {'num_leaves': 63, 'max_depth': 7, 'learning_rate': 0.010496990541124216, 'min_data_in_leaf': 65, 'lambda_l1': 1.4430289533104725, 'lambda_l2': 1.485113619277876, 'feature_fraction': 0.869944621340081, 'bagging_fraction': 0.6259156281069316, 'bagging_freq': 8, 'n_estimators': 146}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:33,860] Trial 8 finished with value: 0.8090608465608466 and parameters: {'num_leaves': 66, 'max_depth': 11, 'learning_rate': 0.03978082223673843, 'min_data_in_leaf': 41, 'lambda_l1': 0.6908664112597581, 'lambda_l2': 0.7178483118508193, 'feature_fraction': 0.8553621624183224, 'bagging_fraction': 0.8231451149743245, 'bagging_freq': 14, 'n_estimators': 289}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:35,238] Trial 9 finished with value: 0.8128306878306878 and parameters: {'num_leaves': 43, 'max_depth': 12, 'learning_rate': 0.07847065437552077, 'min_data_in_leaf': 57, 'lambda_l1': 1.5648376419136658, 'lambda_l2': 1.0382116330923423, 'feature_fraction': 0.7829564902836978, 'bagging_fraction': 0.7496393564254924, 'bagging_freq': 5, 'n_estimators': 143}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:36,518] Trial 10 finished with value: 0.8239417989417991 and parameters: {'num_leaves': 70, 'max_depth': 12, 'learning_rate': 0.09725833997090795, 'min_data_in_leaf': 62, 'lambda_l1': 1.278327660615554, 'lambda_l2': 1.8245631110367835, 'feature_fraction': 0.9359197610808969, 'bagging_fraction': 0.699777962029205, 'bagging_freq': 7, 'n_estimators': 382}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:37,967] Trial 11 finished with value: 0.8201719576719577 and parameters: {'num_leaves': 52, 'max_depth': 9, 'learning_rate': 0.0594435658605193, 'min_data_in_leaf': 52, 'lambda_l1': 0.9578152044085906, 'lambda_l2': 1.1294511911658682, 'feature_fraction': 0.6026846244305095, 'bagging_fraction': 0.9492423868755886, 'bagging_freq': 5, 'n_estimators': 480}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:39,321] Trial 12 finished with value: 0.8220238095238097 and parameters: {'num_leaves': 48, 'max_depth': 9, 'learning_rate': 0.09948252090193968, 'min_data_in_leaf': 48, 'lambda_l1': 0.1809971963086821, 'lambda_l2': 1.9533405243270519, 'feature_fraction': 0.6524377702686985, 'bagging_fraction': 0.849192230774694, 'bagging_freq': 6, 'n_estimators': 480}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:40,397] Trial 13 finished with value: 0.8203703703703704 and parameters: {'num_leaves': 57, 'max_depth': 9, 'learning_rate': 0.06317270186694052, 'min_data_in_leaf': 60, 'lambda_l1': 1.1495058510837326, 'lambda_l2': 0.8820168662125405, 'feature_fraction': 0.7819408655189566, 'bagging_fraction': 0.7062062053109952, 'bagging_freq': 7, 'n_estimators': 389}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:41,766] Trial 14 finished with value: 0.8312169312169313 and parameters: {'num_leaves': 63, 'max_depth': 6, 'learning_rate': 0.086758159644485, 'min_data_in_leaf': 54, 'lambda_l1': 0.7852727161002804, 'lambda_l2': 1.3233366241195352, 'feature_fraction': 0.6676266939408172, 'bagging_fraction': 0.8690089381516137, 'bagging_freq': 5, 'n_estimators': 226}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:42,951] Trial 15 finished with value: 0.8167328042328043 and parameters: {'num_leaves': 70, 'max_depth': 6, 'learning_rate': 0.0703490628344398, 'min_data_in_leaf': 64, 'lambda_l1': 1.7527539429819652, 'lambda_l2': 0.13973577631846734, 'feature_fraction': 0.7260949625770574, 'bagging_fraction': 0.6925914147672212, 'bagging_freq': 8, 'n_estimators': 224}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:44,333] Trial 16 finished with value: 0.8203042328042329 and parameters: {'num_leaves': 63, 'max_depth': 12, 'learning_rate': 0.09101933531047046, 'min_data_in_leaf': 54, 'lambda_l1': 0.8933593140492746, 'lambda_l2': 1.3359654129531644, 'feature_fraction': 0.7481442798995964, 'bagging_fraction': 0.6689594385873573, 'bagging_freq': 15, 'n_estimators': 233}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:45,967] Trial 17 finished with value: 0.8111111111111111 and parameters: {'num_leaves': 65, 'max_depth': 13, 'learning_rate': 0.04751915691818222, 'min_data_in_leaf': 44, 'lambda_l1': 1.2692412721390265, 'lambda_l2': 1.8150485825591463, 'feature_fraction': 0.6634517629870851, 'bagging_fraction': 0.8296153420475376, 'bagging_freq': 7, 'n_estimators': 335}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:47,177] Trial 18 finished with value: 0.809457671957672 and parameters: {'num_leaves': 67, 'max_depth': 11, 'learning_rate': 0.06959802988526621, 'min_data_in_leaf': 55, 'lambda_l1': 1.5453714792490176, 'lambda_l2': 1.955037913249009, 'feature_fraction': 0.6019147362415651, 'bagging_fraction': 0.7423338246834603, 'bagging_freq': 9, 'n_estimators': 259}. Best is trial 5 with value: 0.8331349206349208.
# [I 2024-12-14 16:31:48,248] Trial 19 finished with value: 0.8293650793650794 and parameters: {'num_leaves': 62, 'max_depth': 6, 'learning_rate': 0.0873364961856597, 'min_data_in_leaf': 65, 'lambda_l1': 0.8514063112911621, 'lambda_l2': 1.3363660344946062, 'feature_fraction': 0.8443338240018903, 'bagging_fraction': 0.6040673365696436, 'bagging_freq': 6, 'n_estimators': 193}. Best is trial 5 with value: 0.8331349206349208.
# Best trial: {'num_leaves': 70, 'max_depth': 12, 'learning_rate': 0.09455490474077703, 'min_data_in_leaf': 67, 'lambda_l1': 1.2360099597410619, 'lambda_l2': 1.851561046543922, 'feature_fraction': 0.6309723757181718, 'bagging_fraction': 0.6685940018467008, 'bagging_freq': 5, 'n_estimators': 230}

# %% [markdown]
# #### Testing

# %%
best_params = {'num_leaves': 70, 'max_depth': 12, 'learning_rate': 0.09455490474077703, 'min_data_in_leaf': 67, 'lambda_l1': 1.2360099597410619, 'lambda_l2': 1.851561046543922, 'feature_fraction': 0.6309723757181718, 'bagging_fraction': 0.6685940018467008, 'bagging_freq': 5, 'n_estimators': 230}
model = lgb.LGBMClassifier(**best_params, verbose = -1)
model.fit(X, y)
# Out:
# LGBMClassifier(bagging_fraction=0.6685940018467008, bagging_freq=5,
#                feature_fraction=0.6309723757181718,
#                lambda_l1=1.2360099597410619, lambda_l2=1.851561046543922,
#                learning_rate=0.09455490474077703, max_depth=12,
#                min_data_in_leaf=67, n_estimators=230, num_leaves=70,
#                verbose=-1)

# %%
print('LGBM scores')
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"RocAuc: {roc_auc_score(y_test, y_pred)}")
print(f"F1 : {f1_score(y_test, y_pred)}")
# Out:
# LGBM scores
# Accuracy: 0.8248175182481752
# RocAuc: 0.6963163906339235
# F1 : 0.5555555555555556
